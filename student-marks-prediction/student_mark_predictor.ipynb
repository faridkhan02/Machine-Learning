# %%
#  Business Problem

# %% [markdown]
# #  Business Problem

# %% [markdown]
# ### import libarries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv(r"D:\telegram\student_info.csv")

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# # Discover and visulize the data to gain insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# #  Discriptive statics

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.scatter( x =df.study_hours, y = df.student_marks)
plt.xlabel("Student Study Hours")
plt.ylabel("Student Mrarks")
plt.title("Scatter plot of Students study Hours vs Student Marks")
plt.show()

# %% [markdown]
# # Preapre the data for Machine Learning algorithms

# %%
# Data Cleaning

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2 =df

# %%
df2=df.fillna(df.mean()).round(2)

# %%
df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
df2
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2           7.00          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    200 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df2.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2         7.00          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df2.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
# Split Dataset

# %%
X = df2.drop("student_marks",axis = "columns")
Y = df2.drop("study_hours",axis="columns")
print("shape of X ",X.shape)
print("shape of Y ", Y.shape)
# Out:
# shape of X  (200, 1)
# shape of Y  (200, 1)

# %%
X
# Out:
#      study_hours
# 0           6.83
# 1           6.56
# 2           7.00
# 3           5.67
# 4           8.67
# ..           ...
# 195         7.53
# 196         8.56
# 197         8.94
# 198         6.60
# 199         8.35
#
# [200 rows x 1 columns]

# %%
Y
# Out:
#      student_marks
# 0            78.50
# 1            76.74
# 2            78.68
# 3            71.82
# 4            84.19
# ..             ...
# 195          81.67
# 196          84.68
# 197          86.75
# 198          78.05
# 199          83.50
#
# [200 rows x 1 columns]

# %%
# ML Algorithm

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)
print("shappe of the X_train",X_train.shape)
print("shape of the Y_tain",Y_train.shape)
print("shape of X_test",X_test.shape)
print("shape of Y_test",Y_test.shape)
# Out:
# shappe of the X_train (160, 1)
# shape of the Y_tain (160, 1)
# shape of X_test (40, 1)
# shape of Y_test (40, 1)

# %%
X_train
# Out:
#      study_hours
# 134         6.51
# 66          7.86
# 26          6.51
# 113         7.95
# 168         7.95
# ..           ...
# 67          8.26
# 192         8.71
# 117         8.83
# 47          5.01
# 172         7.35
#
# [160 rows x 1 columns]

# %%
Y_train
# Out:
#      student_marks
# 134          78.39
# 66           81.25
# 26           74.75
# 113          80.86
# 168          82.68
# ..             ...
# 67           81.70
# 192          84.03
# 117          85.04
# 47           70.11
# 172          77.78
#
# [160 rows x 1 columns]

# %%
X_test
print(type(X_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
Y_test
# Out:
#      student_marks
# 18           82.50
# 170          71.18
# 107          73.25
# 98           83.64
# 177          73.64
# 182          86.99
# 5            81.18
# 146          82.75
# 12           79.50
# 152          81.70
# 61           79.41
# 125          85.95
# 180          77.19
# 154          78.45
# 80           84.00
# 7            85.46
# 33           84.35
# 130          73.19
# 37           78.21
# 74           77.59
# 183          83.87
# 145          85.15
# 45           72.96
# 159          80.72
# 60           73.61
# 123          79.53
# 179          78.17
# 185          79.63
# 122          76.83
# 44           82.38
# 16           76.04
# 55           85.48
# 150          71.87
# 111          75.04
# 22           70.67
# 189          79.87
# 129          74.49
# 4            84.19
# 83           75.36
# 106          72.10

# %% [markdown]
# # Select a model and train it

# %%
# y = mx + c
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
lr.coef_ #m
# Out:
# array([[3.93028185]])

# %%
lr.intercept_# c
# Out:
# array([50.45086928])

# %%
m = 3.92
c = 50.44
y = m * 10 + c
y
# Out:
# 89.64

# %%
m = 3.92
c = 50.44
y = m * 12 + c
y
# Out:
# 97.47999999999999

# %%
lr.predict([[13]]).round(2)
# Out:
# c:\Users\khana\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[101.54]])

# %%
lr.predict([[5]])[0][0].round(2)
# Out:
# c:\Users\khana\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(70.1)

# %%
y_pred =lr.predict(X_test)
y_pred
# Out:
# array([[83.50453963],
#        [70.84903207],
#        [72.93208145],
#        [85.3517721 ],
#        [73.20720118],
#        [84.48711009],
#        [80.12449724],
#        [81.85382125],
#        [80.91055361],
#        [82.20754662],
#        [78.9847155 ],
#        [84.84083546],
#        [77.84493377],
#        [77.68772249],
#        [83.2294199 ],
#        [85.7841031 ],
#        [84.95874391],
#        [72.61765891],
#        [78.70959577],
#        [79.18122959],
#        [84.290596  ],
#        [85.62689183],
#        [74.7400111 ],
#        [81.34288461],
#        [72.02811663],
#        [80.39961697],
#        [78.9847155 ],
#        [82.08963816],
#        [77.96284222],
#        [82.24684944],
#        [75.44746184],
#        [84.60501855],
#        [71.63508844],
#        [75.48676466],
#        [70.29879262],
#        [78.9847155 ],
#        [75.32955338],
#        [84.52641291],
#        [74.07186319],
#        [71.43857435]])

# %%
pd.DataFrame(np.c_[X_test,Y_test,y_pred],columns=["study hours","student_makrs_origin","student_marks_predicted"])
# Out:
#     study hours  student_makrs_origin  student_marks_predicted
# 0          8.41                 82.50                83.504540
# 1          5.19                 71.18                70.849032
# 2          5.72                 73.25                72.932081
# 3          8.88                 83.64                85.351772
# 4          5.79                 73.64                73.207201
# 5          8.66                 86.99                84.487110
# 6          7.55                 81.18                80.124497
# 7          7.99                 82.75                81.853821
# 8          7.75                 79.50                80.910554
# 9          8.08                 81.70                82.207547
# 10         7.26                 79.41                78.984716
# 11         8.75                 85.95                84.840835
# 12         6.97                 77.19                77.844934
# 13         6.93                 78.45                77.687722
# ...

# %%
print(X_test.shape)
print(Y_test.shape)
print(y_pred.shape)
# Out:
# (40, 1)
# (40, 1)
# (40, 1)

# %% [markdown]
# # Fine-tune your model

# %%
lr
# Out:
# LinearRegression()

# %%
lr.score(X_test,Y_test)# bais
# Out:
# 0.9521478358389485

# %%
lr.score(X_train,Y_train) # variance
# Out:
# 0.9584174286541537

# %%
plt.scatter(X_train,Y_train)

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_train,lr.predict(X_train),color="red")

# %% [markdown]
# # Present your solution

# %% [markdown]
# # Save ML Model

# %%
lr
# Out:
# LinearRegression()

# %%
import joblib # create pipeline
joblib.dump(lr, "Desktop.pkl")
# Out:
# ['Desktop.pkl']

# %%
pwd
# Out:
# 'c:\\machine learning\\regression\\student-marks-prediction'

# %%
model = joblib.load("Desktop.pkl") # pickle

# %%
pwd
# Out:
# 'c:\\machine learning\\regression\\student-marks-prediction'

# %% [markdown]
# # Launch, monitor, and maintain your system

# %%
__name__
# Out:
# '__main__'
